# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://music.bugs.co.kr/chart' 
resp = requests.get(url)

# %%
html = resp.content
soup = BeautifulSoup(html, 'html.parser')
table = soup.find('table')

# %%
table
# Out:
# <table class="list trackList byChart">
# <caption>곡 목록</caption>
# <thead>
# <tr>
# <th class="check" scope="col"></th>
# <th class="ranking" scope="col"><span>순위</span></th>
# <th class="albumArt" scope="col"></th>
# <th class="trackInfo" scope="col"></th>
# <th class="title" scope="col"><span>곡</span></th>
# <th class="artist" scope="col"><span>아티스트</span></th>
# <th class="album" scope="col"><span>앨범</span></th>
# <th class="action play" scope="col"><span>듣기</span></th>
# <th class="action add01" scope="col"><span>재생목록</span></th>
# <th class="action add02" scope="col"><span>내앨범</span></th>
# <th class="action download" scope="col"><span>다운</span></th>
# <th class="action mv" scope="col"><span>영상</span></th>
# <th class="action etc" scope="col"><span>기타</span></th>
# </tr>
# </thead>
# <tbody>
# <tr albumid="4080525" artistid="80177857" multiartist="N" mvid="611981" rowtype="track" trackid="6178609">
# <input name="_isStream" type="hidden" value="6178609">
# ...

# %%
th = table.find_all('th')

# %%
th
# Out:
# [<th class="check" scope="col"></th>,
#  <th class="ranking" scope="col"><span>순위</span></th>,
#  <th class="albumArt" scope="col"></th>,
#  <th class="trackInfo" scope="col"></th>,
#  <th class="title" scope="col"><span>곡</span></th>,
#  <th class="artist" scope="col"><span>아티스트</span></th>,
#  <th class="album" scope="col"><span>앨범</span></th>,
#  <th class="action play" scope="col"><span>듣기</span></th>,
#  <th class="action add01" scope="col"><span>재생목록</span></th>,
#  <th class="action add02" scope="col"><span>내앨범</span></th>,
#  <th class="action download" scope="col"><span>다운</span></th>,
#  <th class="action mv" scope="col"><span>영상</span></th>,
#  <th class="action etc" scope="col"><span>기타</span></th>,
#  <th scope="row">
#  <p adult_yn="N" class="title">
#  <a adultcheckval="1" aria-label="새창" href="javascript:;" onclick="bugs.wiselog.area('list_tr_09_chart');bugs.music.listen('6178609',true);
#  " title="ILLELLA (일낼라)">ILLELLA (일낼라)</a>
#  </p>
#  </th>,
# ...

# %%
th.p.a.string
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43808\2894187022.py in <module>
# ----> 1 th.p.a.string
#
# ~\anaconda3\envs\silcream\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2288         """Raise a helpful exception to explain a common code fix."""
#    2289         raise AttributeError(
# -> 2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# AttributeError: ResultSet object has no attribute 'p'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
td[0]
# Out:
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="ILLELLA (일낼라)" type="checkbox" value="6178609"/></td>

# %%
print(soup.find('tbody').prettify())
# Out:
# <tbody>
#  <tr albumid="4080525" artistid="80177857" multiartist="N" mvid="611981" rowtype="track" trackid="6178609">
#   <input name="_isStream" type="hidden" value="6178609">
#    <input name="_isDown" type="hidden" value="6178609">
#     <td class="check">
#      <input buyminquality="T" disc_id="1" name="check" title="ILLELLA (일낼라)" type="checkbox" value="6178609"/>
#     </td>
#     <td>
#      <div class="ranking">
#       <strong>
#        1
#       </strong>
#       <p class="change none">
#        <em>
#         0
#        </em>
#        <span>
#         변동없음
#        </span>
#       </p>
#      </div>
#     </td>
#     <td>
#      <a class="thumbnail" href="https://music.bugs.co.kr/album/4080525?wl_ref=list_tr_07_chart" onclick="
# ">
#       <span class="mask">
#       </span>
#       <img alt="MIC ON 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40805/4080525.jpg?version=20221012063733.0"/>
#      </a>
#     </td>
#     <td>
# ...

# %%
tbody_tag = soup.find('tbody')
tbody_tag.find_all('tr')[0]
# Out:
# <tr albumid="4080525" artistid="80177857" multiartist="N" mvid="611981" rowtype="track" trackid="6178609">
# <input name="_isStream" type="hidden" value="6178609">
# <input name="_isDown" type="hidden" value="6178609">
# <td class="check"><input buyminquality="T" disc_id="1" name="check" title="ILLELLA (일낼라)" type="checkbox" value="6178609"/></td>
# <td>
# <div class="ranking">
# <strong>1</strong>
# <p class="change none"><em>0</em><span>변동없음</span></p>
# </div>
# </td>
# <td>
# <a class="thumbnail" href="https://music.bugs.co.kr/album/4080525?wl_ref=list_tr_07_chart" onclick="
# ">
# <span class="mask"></span>
# <img alt="MIC ON 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40805/4080525.jpg?version=20221012063733.0"/>
# </a>
# </td>
# <td>
# <a class="trackInfo" href="https://music.bugs.co.kr/track/6178609?wl_ref=list_tr_08_chart" onclick="
# ">곡정보</a>
# </td>
# <th scope="row">
# <p adult_yn="N" class="title">
# ...

# %%
tr_tags = tbody_tag.find_all('tr')

# %%
tr_tags
# Out:
# [<tr albumid="4080525" artistid="80177857" multiartist="N" mvid="611981" rowtype="track" trackid="6178609">
#  <input name="_isStream" type="hidden" value="6178609">
#  <input name="_isDown" type="hidden" value="6178609">
#  <td class="check"><input buyminquality="T" disc_id="1" name="check" title="ILLELLA (일낼라)" type="checkbox" value="6178609"/></td>
#  <td>
#  <div class="ranking">
#  <strong>1</strong>
#  <p class="change none"><em>0</em><span>변동없음</span></p>
#  </div>
#  </td>
#  <td>
#  <a class="thumbnail" href="https://music.bugs.co.kr/album/4080525?wl_ref=list_tr_07_chart" onclick="
#  ">
#  <span class="mask"></span>
#  <img alt="MIC ON 대표이미지" onerror="bugs.utils.imgError(this);" src="https://image.bugsm.co.kr/album/images/50/40805/4080525.jpg?version=20221012063733.0"/>
#  </a>
#  </td>
#  <td>
#  <a class="trackInfo" href="https://music.bugs.co.kr/track/6178609?wl_ref=list_tr_08_chart" onclick="
#  ">곡정보</a>
#  </td>
#  <th scope="row">
#  <p adult_yn="N" class="title">
# ...

# %%
tr_tags[0].find_all('td')[0].string

# %%
result1 = []
url = 'https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=%d&sido=&gugun=&store=' % page
resp = requests.get(url)
html = resp.content
soup = BeautifulSoup(html, 'html.parser')
    
tbody_tag = soup.find('tbody')
tr_tags = tbody_tag.find_all('tr')
for tr in tr_tags :
    td_tags = tr.find_all('td')

    loc = td_tags[0].string
    name = td_tags[1].string
    addr = td_tags[3].string
    phone = td_tags[5].string
        result1.append([loc, name, addr, phone])
    print(f'-----------{page} page completed-----')
